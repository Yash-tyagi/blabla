# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt

# %%
image = cv.imread('26.jpg')
dst = cv.fastNlMeansDenoisingColored(image,None,10,10,7,21)
plt.subplot(121),plt.imshow(image)
plt.subplot(122),plt.imshow(dst)
plt.show()

# %%
image_med = cv.medianBlur(image,5)
plt.subplot(121),plt.imshow(image_med)
dst = cv.fastNlMeansDenoisingColored(image_med,None,10,10,7,21)
